# %%
import logging
import pandas as pd
import requests
from requests import get
from bs4 import BeautifulSoup
from requests.auth import HTTPProxyAuth
logging.basicConfig(level=logging.INFO)

# %%
response=requests.get(
        url='https://app.scrapingbee.com/api/v1/',
        params={
            'api_key': 'TI1CCXUDLDD7ZCV1MTQM6KRO8V2UP6WETYQMEEBBX18BCR0YGSZ5YMYDXO4FFQZDEG1MXODBYFX01VAX',
            'url': 'https://www.booking.com/searchresults.fr.html?label=fr-fr-booking-desktop-DCpBIW3k2*WIo8XuzMdB9AS652796013276%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-65526620%3Alp9056191%3Ali%3Adec%3Adm&aid=2311236&ss=France&ssne=France&ssne_untouched=France&lang=fr&src=index&dest_id=73&dest_type=country&checkin=2023-12-11&checkout=2023-12-16&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&nflt=ht_id%3D204%3Bhotelfacility%3D433%3Bclass%3D4%3Bmealplan%3D1%3Bpopular_activities%3D253',  
            },
        
    )
print('Response HTTP Status Code: ', response.status_code)
print('Response HTTP Response Body: ', response.content)
print(response.text[:500])
# Out:
# Response HTTP Status Code:  200
# ...

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text,"html.parser")
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
booking = html_soup.find_all("div",class_="c82435a4b8 a178069f51 a6ae3c2b40 a18aeea94d d794b7a0f7 f53e278e95 c6710787a4")
len(booking)
# Out:
# 25

# %%
type(booking)
# Out:
# bs4.element.ResultSet

# %%
print(booking[0].prettify())
# Out:
# <div class="c82435a4b8 a178069f51 a6ae3c2b40 a18aeea94d d794b7a0f7 f53e278e95 c6710787a4" data-testid="property-card" style="--bui_box_padding--s:4">
#  <div class="c066246e13" data-testid="property-card-container">
#   <div class="a5922b8ca1">
#    <div class="e952b01718">
# ...

# %%
#Extraire le nom du premier hotel:
first_hotel=booking[0].find("div",class_="f6431b446c a15b38c233")
first_hotel.text
# Out:
# 'Paxton Paris MLV'

# %%
#Extraire l'URL du premier hotel:
first_url=booking[0].find("a").get("href")
first_url
# Out:
# 'https://www.booking.com/hotel/fr/paxton-residence-spa.fr.html?label=fr-fr-booking-desktop-DCpBIW3k2*WIo8XuzMdB9AS652796013276%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-65526620%3Alp9056191%3Ali%3Adec%3Adm&aid=2311236&ucfs=1&arphpl=1&checkin=2023-12-11&checkout=2023-12-16&dest_id=73&dest_type=country&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_id%3D204%3Bhotelfacility%3D433%3Bclass%3D4%3Bmealplan%3D1%3Bpopular_activities%3D253&srpvid=f07e4e9ae8ea0272&srepoch=1700824245&all_sr_blocks=5426331_91902903_0_1_0&highlighted_blocks=5426331_91902903_0_1_0&matching_block_id=5426331_91902903_0_1_0&sr_pri_blocks=5426331_91902903_0_1_0__85520&from_sustainable_property_sr=1&from=searchresults#hotelTmpl'

# %%
#Extraire les cordonnées GPS et la ville du premier hotel:
first_coordinates=booking[0].find("span",class_="aee5343fdb def9bc142a")
if "," in first_coordinates.text:
    print(f"la ville est {first_coordinates.text.split(',')[1]}")
    print("conversion en latitude et longitude via API openstreetmap")
    city1=first_coordinates.text.split(',')[1]
    country="France"
    r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city1},{country}")
    json1_data=r.json()
    latitde1= json1_data[0]['lat']
    longitude1= json1_data[0]['lon']
    print("...Done")
    print(f"la latitude de {city1} est:{latitde1}")
    print(f"la longitude {city1} de est:{longitude1}")
else:
    print(first_coordinates.text)
    print("conversion en latitude et longitude via API openstreetmap")
    city1=first_coordinates.text
    country="France"
    r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city1},{country}")
    json1_data=r.json()
    latitde1= json1_data[0]['lat']
    longitude1= json1_data[0]['lon']
    print("...Done")
    print(f"la latitude de {city1} est:{latitde1}")
    print(f"la longitude de {city1} de est:{longitude1}")
# Out:
# Ferrières-en-Brie
# conversion en latitude et longitude via API openstreetmap
# ...Done
# la latitude de Ferrières-en-Brie est:48.8213887
# la longitude de Ferrières-en-Brie de est:2.7045126

# %%
#Extraire le score du premier hotel:
first_score=booking[0].find("div",class_="a3b8729ab1 d86cee9b25")
print(first_score.text)
# Out:
# 8,0

# %%
#Script pour scraper toute la page: 
names=[]
urls=[]
citys=[]
lat=[]
lon=[]
scores=[]
for hotel in range(0,len(booking)):
    name=booking[hotel].find("div",class_="f6431b446c a15b38c233")
    name=name.text
    names.append(name)

    url=booking[hotel].find("a").get("href")
    urls.append(url)

    coordinate=booking[hotel].find("span",class_="aee5343fdb def9bc142a")
    if ","in coordinate.text:
        city=coordinate.text.split(',')[1]
        country="France"
        r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city},{country}")
        json_data=r.json()
        latitde= json_data[0]['lat']
        longitude= json_data[0]['lon']
        citys.append(city)
        lat.append(latitde)
        lon.append(longitude)
    else:
        city=coordinate.text
        country="France"
        r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city},{country}")
        json_data=r.json()
        latitde= json_data[0]['lat']
        longitude= json_data[0]['lon']
        citys.append(city)
        lat.append(latitde)
        lon.append(longitude)

    score=booking[hotel].find("div",class_="a3b8729ab1 d86cee9b25")
    score=score.text
    scores.append(score)

# %%
df=pd.DataFrame(list(zip(names,scores,citys,lat,lon,urls)),columns=["hotel","scores","city","latitude","longitude","url"])
df
# Out:
#                                             hotel scores                city  \
# 0                                Paxton Paris MLV    8,0   Ferrières-en-Brie
# 1                                       MOB House    8,5          Saint-Ouen
# 2                      Golden Tulip Pornic Suites    8,4              Pornic
# 3                         Les Elmes - Hôtel & Spa    8,7     Banyuls-sur-Mer
# 4       Radisson Blu Hotel Paris, Marne-la-Vallée    7,8     Magny-le-Hongre
# 5                     Le Grand Pavillon Chantilly    8,0           Chantilly
# 6      Holiday Inn Calais Coquelles, an IHG Hotel    8,0           Coquelles
# 7            Résidence Prestige Odalys Mendi Alde    7,9           La Clusaz
# 8         Best Western Plus Hôtel Escapade Senlis    8,4              Senlis
# 9         Radisson Blu Hotel Marseille Vieux Port    7,8           Marseille
# 10                  Residhome Suites Paris Sénart    8,2           Lieusaint
# ...

# %%
#avec le proxy, pas besoin de contrôler le taux de requetes envoyées:
pages=[str(i) for i in range(0,225,25)] #les liens des pages s'incriment avec &offset=0 puis 25 puis 50 puis...
#redéclarer les listes:
names=[]
urls=[]
citys=[]
lat=[]
lon=[]
scores=[]
#boucles pour chaque page:
for page in pages:
    response=requests.get(
    url='https://app.scrapingbee.com/api/v1/',
    params={
        'api_key': 'TI1CCXUDLDD7ZCV1MTQM6KRO8V2UP6WETYQMEEBBX18BCR0YGSZ5YMYDXO4FFQZDEG1MXODBYFX01VAX',
        'url':f'https://www.booking.com/searchresults.fr.html?label=fr-fr-booking-desktop-DCpBIW3k2*WIo8XuzMdB9AS652796013276%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-65526620%3Alp9056191%3Ali%3Adec%3Adm&aid=2311236&ss=France&ssne=France&ssne_untouched=France&lang=fr&src=index&dest_id=73&dest_type=country&checkin=2023-12-11&checkout=2023-12-16&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&nflt=ht_id%3D204%3Bhotelfacility%3D433%3Bclass%3D4%3Bmealplan%3D1%3Bpopular_activities%3D253&offset={page}',  
        },    
    )
    html_soup = BeautifulSoup(response.text, 'html.parser')
    booking = html_soup.find_all("div",class_="c82435a4b8 a178069f51 a6ae3c2b40 a18aeea94d d794b7a0f7 f53e278e95 c6710787a4")
    for hotel in range(0,len(booking)):
        name=booking[hotel].find("div",class_="f6431b446c a15b38c233")
        name=name.text
        names.append(name)

        url=booking[hotel].find("a").get("href")
        urls.append(url)

        coordinate=booking[hotel].find("span",class_="aee5343fdb def9bc142a")
        if ","in coordinate.text:
            city=coordinate.text.split(',')[1]
            country="France"
            r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city},{country}")
            json_data=r.json()
            latitde= json_data[0]['lat']
            longitude= json_data[0]['lon']
            citys.append(city)
            lat.append(latitde)
            lon.append(longitude)
        else:
            city=coordinate.text
            country="France"
            r=requests.get(f"https://nominatim.openstreetmap.org/search?format=json&q={city},{country}")
            json_data=r.json()
            latitde= json_data[0]['lat']
            longitude= json_data[0]['lon']
            citys.append(city)
            lat.append(latitde)
            lon.append(longitude)

        if booking[hotel].find("div",class_="a3b8729ab1 d86cee9b25"):
            score=booking[hotel].find("div",class_="a3b8729ab1 d86cee9b25")
            score=score.text
            scores.append(score)
        else:
            score="NaN"
            scores.append(score)

# %%
df=pd.DataFrame(list(zip(names,scores,citys,lat,lon,urls)),columns=["hotel","scores","city","latitude","longitude","url"])
df
# Out:
#                            hotel scores               city    latitude  \
# 0               Paxton Paris MLV    8,0  Ferrières-en-Brie  48.8213887
# 1                      MOB House    8,5         Saint-Ouen    50.03683
# 2        Les Elmes - Hôtel & Spa    8,7    Banyuls-sur-Mer  42.4794084
# 3            Hotel Eiffel Blomet    8,7              Paris  48.8588897
# 4     Golden Tulip Pornic Suites    8,4             Pornic  47.1152695
# ..                           ...    ...                ...         ...
# 211   Hotel Le Hameau Du Kashmir    8,1        Val Thorens  45.2979109
# 212    Novotel Bordeaux Mérignac    7,3           Mérignac   44.842168
# 213     Pullman Toulouse Airport    8,2            Blagnac     43.6434
# 214  Hotel Astra Opera - Astotel    NaN              Paris  48.8588897
# 215  Hotel Residence Lido Marana    8,4            Furiani  42.6584811
#
#               longitude                                                url
# ...

# %%
#Enregistrer la dataframe au format csv afin d'eviter de relancer le proxy qui n'est pas gratuit au dela de 1000 appels
df.to_csv("data_booking.csv")

# %%
a=df.hotel.value_counts().reset_index()
a
# Out:
#                                                  index  hotel
# 0                                  Domaine des Dryades      3
# 1                   LOISIUM Wine & Spa Hotel Champagne      3
# 2                                   Golden Tulip Reims      3
# 3                     Abbaye des Capucins Spa & Resort      3
# 4    Hotel Yac Paris Clichy, a member of Radisson I...      3
# ..                                                 ...    ...
# 178                        La Clairière bio & spahotel      1
# 179                            Canopy by Hilton Cannes      1
# 180                               Pullman Bordeaux Lac      1
# 181                     Novotel Nice Centre Vieux Nice      1
# 182                        Hotel Astra Opera - Astotel      1
#
# [183 rows x 2 columns]
